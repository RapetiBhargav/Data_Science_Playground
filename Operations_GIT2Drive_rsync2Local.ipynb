# %% [markdown]
# <a href="https://colab.research.google.com/github/RapetiBhargav/Data_Science_Playground/blob/main/Operations_GIT2Drive_rsync2Local.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab
ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)
drive.mount(ROOT)         # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# Clone github repository setup
# import join used to join ROOT path and MY_GOOGLE_DRIVE_PATH
from os.path import join  

MY_GOOGLE_DRIVE_PATH = 'My Drive/NLPExperiments'  
GIT_USERNAME = "RapetiBhargav"
GIT_NAME="RapetiBhargav"
GIT_TOKEN = "f1e1c68907ebfec17573d79cccf6023e5ac8c150"  
GIT_REPOSITORY = "practical-nlp" 

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)
# Out:
# PROJECT_PATH:  /content/drive/My Drive/NLPExperiments

# %%
# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"

# %%
#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# GIT_PATH:  https://f1e1c68907ebfec17573d79cccf6023e5ac8c150@github.com/RapetiBhargav/practical-nlp.git

# %%
# !mkdir ./temp
# !git clone "{GIT_PATH}" ./temp
# !mv ./temp/* "{PROJECT_PATH}"
# !rm -rf ./temp
# !rsync -aP --exclude=Data/ "{PROJECT_PATH}"/*  ./
# Out:
# Cloning into './temp'...
# remote: Enumerating objects: 148, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 1064 (delta 76), reused 22 (delta 7), pack-reused 916
# Receiving objects: 100% (1064/1064), 79.46 MiB | 22.25 MiB/s, done.
# Resolving deltas: 100% (578/578), done.
# sending incremental file list
# Contributing.md
#           3,658 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=123/124)
# Disclaimers.md
#             585 100%  571.29kB/s    0:00:00 (xfr#2, to-chk=122/124)
# LICENSE
#           1,057 100%    1.01MB/s    0:00:00 (xfr#3, to-chk=121/124)
# README.md
#           4,516 100%    4.31MB/s    0:00:00 (xfr#4, to-chk=120/124)
# requirements.txt
#           3,480 100%    1.66MB/s    0:00:00 (xfr#5, to-chk=119/124)
# roadmap.md
#           1,098 100%  536.13kB/s    0:00:00 (xfr#6, to-chk=118/124)
# Ch1/
# Ch1/README.md
#           2,294 100%  746.74kB/s    0:00:00 (xfr#7, to-chk=106/124)
# Ch10/
# ...

# %%
#Saving it at the end of the day
# !cp -r ./Ch* "{PROJECT_PATH}"

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# Ch1   Ch2  Ch5	Ch8		 Disclaimers.md  README.md	   sample_data
# Ch10  Ch3  Ch6	Ch9		 drive		 requirements.txt
# Ch11  Ch4  Ch7	Contributing.md  LICENSE	 roadmap.md

# %%
GIT_COMMIT_MESSAGE='sample git commit from Colab'
GIT_BRANCH_NAME="master"
GIT_EMAIL="rapeti.bhargav@gmail.com"
GIT_NAME="RapetiBhargav"

# !mkdir ./temp
# !git clone "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" ./temp
# !rsync -aP --exclude=Data/ "{PROJECT_PATH}"/* ./temp

# %cd ./temp
# !git add .
# !git commit -m '"{GIT_COMMIT_MESSAGE}"'
# !git config --global user.email "rapeti.bhargav@gmail.com"
# !git config --global user.name "RapetiBhargav"
# !git push origin "{GIT_BRANCH_NAME}"
# %cd /content
# !rm -rf ./temp
# Out:
# Cloning into './temp'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 1067 (delta 78), reused 25 (delta 8), pack-reused 916
# Receiving objects: 100% (1067/1067), 79.46 MiB | 10.84 MiB/s, done.
# Resolving deltas: 100% (580/580), done.
# sending incremental file list
# Contributing.md
#           3,658 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=123/124)
# Disclaimers.md
#             585 100%  571.29kB/s    0:00:00 (xfr#2, to-chk=122/124)
# LICENSE
#           1,057 100%    1.01MB/s    0:00:00 (xfr#3, to-chk=121/124)
# README.md
#           4,516 100%    4.31MB/s    0:00:00 (xfr#4, to-chk=120/124)
# requirements.txt
#           3,480 100%    1.66MB/s    0:00:00 (xfr#5, to-chk=119/124)
# roadmap.md
#           1,098 100%  536.13kB/s    0:00:00 (xfr#6, to-chk=118/124)
# Ch1/
# Ch1/README.md
#           2,294 100%  560.06kB/s    0:00:00 (xfr#7, to-chk=106/124)
# Ch10/
# ...
